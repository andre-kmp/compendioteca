# %% [markdown]
# ## Tipos de dados Python

# %% [markdown]
# ### Conceitos chave

# %% [markdown]
# #### Expressões, variáveis e atribuições
# - Regras de precedência
# - Tipos numéricos e expressões algébricas puras (incluindo quociente inteiro (`//`) e resto (`%`))
# - Tipos booleanos, expressões booleanas e uma pitadinha de George Boole
# - Nomes de variáveis (regras e convenções)
# - Operadores de strings (indexação é apresentada aqui)
# - Operadores de listas
# - Mutabilidade
#
# #### Objetos e Classes
# - Ideia de conteiner
# - Tipos (Classes) e valores de objetos
# - Python é uma linguagem orientada a objetos
# - Limite para o tamanho (em bits) que um valor pode ter; notação científica
# - Métodos construtores
# - Conversões de tipo
#
# #### Biblioteca Padrão Python
# - Módulo `math`
# - Módulo `fractions`
# - Turtle Graphics (a primeira vez que vi isso foi nesse livro. Não vou trazer para cá)

# %% [markdown]
# ### Exercícios selecionados

# %% [markdown]
# #### 2.20

# %% [markdown]
# Uma escada encostada diretamente contra uma parede cairá a menos que colocada em um certo ângulo menor que 90 graus. Dadas as variáveis `comprimento` e `ângulo` armazenando o comprimento da escada e o ângulo que ela forma com o solo enquanto encostada na parede, escreva uma expressão Python envolvendo `comprimento` e `ângulo`, que calcule a altura alcançada pela escada. Avalie a expressão para estes valores de `comprimento` e `ângulo`:
#
# (a) 16 pés e 75 graus; (b) 20 pés e 0 graus; (c) 24 pés e 45 graus; (d) 24 pés e 80 graus

# %% [markdown]
# ##### Resolução

# %% [markdown]
# **1. Fórmulas importantes:**
#
# $comprimento = \frac{altura}{sin(ângulo)}$
#
# $radianos = \frac{\pi * \theta}{180}$, onde $\theta = ângulo$

# %%
import math

escadas = {
    '(a)' : [16, 75],
    '(b)' : [20, 0],
    '(c)' : [24, 45],
    '(d)' : [24, 80],
    }

print("As alturas são:")
for escada in escadas:
    comprimento, angulo = escadas[escada][0], escadas[escada][1]
    altura = round(math.sin(math.radians(angulo)) * comprimento)
    escadas[escada].append(altura)
    print(f'{escada} {altura} pés')
# Out:
# As alturas são:
# (a) 15 pés
# (b) 0 pés
# (c) 17 pés
# (d) 24 pés

# %% [markdown]
# **Observação**: não segui o capítulo para resolver esse problema. Selecionei esse exercício por ser um problema de trigonometria.
